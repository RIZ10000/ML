# %% [markdown]
# <a href="https://colab.research.google.com/github/RIZ10000/ML/blob/master/Experiment/EXP_12_J047_121020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# !wget -O AirQualityUCI.zip https://archive.ics.uci.edu/ml/machine-learning-databases/00360/AirQualityUCI.zip
# !unzip AirQualityUCI.zip
df = pd.read_excel('/content/AirQualityUCI.xlsx', parse_dates=[['Date', 'Time']])
df.replace(to_replace=-200.0, value=0.0, inplace=True)
wv = df['NMHC(GT)']
bad_wv = wv == -200.0
wv[bad_wv] = 0.0
# Out:
# --2020-10-30 19:07:24--  https://archive.ics.uci.edu/ml/machine-learning-databases/00360/AirQualityUCI.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1543989 (1.5M) [application/x-httpd-php]
# Saving to: ‘AirQualityUCI.zip’
#
# AirQualityUCI.zip   100%[===================>]   1.47M  8.22MB/s    in 0.2s
#
# 2020-10-30 19:07:24 (8.22 MB/s) - ‘AirQualityUCI.zip’ saved [1543989/1543989]
#
# Archive:  AirQualityUCI.zip
#   inflating: AirQualityUCI.csv
#   inflating: AirQualityUCI.xlsx
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
df.head()
# Out:
#             Date_Time  CO(GT)  PT08.S1(CO)  ...      T         RH        AH
# 0 2004-03-10 18:00:00     2.6      1360.00  ...  13.60  48.875001  0.757754
# 1 2004-03-10 19:00:00     2.0      1292.25  ...  13.30  47.700000  0.725487
# 2 2004-03-10 20:00:00     2.2      1402.00  ...  11.90  53.975000  0.750239
# 3 2004-03-10 21:00:00     2.2      1375.50  ...  11.00  60.000000  0.786713
# 4 2004-03-10 22:00:00     1.6      1272.25  ...  11.15  59.575001  0.788794
#
# [5 rows x 14 columns]

# %%
sns.heatmap(df.corr(), annot=True)

# %%
target = 'NO2(GT)'

# %%
df = df[['CO(GT)','PT08.S1(CO)','C6H6(GT)','PT08.S2(NMHC)','NOx(GT)'	,'PT08.S3(NOx)','NO2(GT)','PT08.S4(NO2)','PT08.S5(O3)','T','RH']]

# %%
X = df.drop(target,axis=1)
y = df[[target]]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y)
value = y_test

# %%
print (x_train.shape)
print (x_test.shape)
print (y_train.shape)
print (y_test.shape)
# Out:
# (7017, 10)
# (2340, 10)
# (7017, 1)
# (2340, 1)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scaler.fit(x_train)
x_train = scaler.fit_transform(x_train)
scaler.fit(x_test)
x_test = scaler.fit_transform(x_test)
scaler.fit(y_train)
y_train = scaler.fit_transform(y_train)
scaler.fit(y_test)
y_test = scaler.fit_transform(y_test)

# %%
x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))
x_test = np.reshape(x_test, (x_test.shape[0],x_test.shape[1],1))
print (x_train.shape)
print (x_test.shape)
# Out:
# (7017, 10, 1)
# (2340, 10, 1)

# %%
print (y_train.shape)
print (y_test.shape)
# Out:
# (7017, 1)
# (2340, 1)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Flatten
def RNN_MODEL():
    # have to convert to 3D for feeding the data
    regressor = Sequential()
    regressor.add(LSTM(units = 50,return_sequences = True))
    regressor.add(Dropout(0.2))
    regressor.add(LSTM(units = 50,return_sequences = True))
    regressor.add(Dropout(0.2))
    regressor.add(LSTM(units = 50))
    regressor.add(Dropout(0.2))
    regressor.add(Dense(units = 1))
    regressor.compile(optimizer = 'adam',loss = 'mean_squared_error',metrics=['accuracy'])
    return regressor
regressor = RNN_MODEL()
regressor.fit(x_train,y_train,epochs = 100)
# Out:
# Epoch 1/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0292 - accuracy: 0.1797
# Epoch 2/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0208 - accuracy: 0.1794
# Epoch 3/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0169 - accuracy: 0.1789
# Epoch 4/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0154 - accuracy: 0.1791
# Epoch 5/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0147 - accuracy: 0.1796
# Epoch 6/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0142 - accuracy: 0.1797
# Epoch 7/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0133 - accuracy: 0.1797
# Epoch 8/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0124 - accuracy: 0.1800
# Epoch 9/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0112 - accuracy: 0.1800
# Epoch 10/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0099 - accuracy: 0.1800
# Epoch 11/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0091 - accuracy: 0.1800
# Epoch 12/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0087 - accuracy: 0.1798
# Epoch 13/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0080 - accuracy: 0.1800
# Epoch 14/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0075 - accuracy: 0.1800
# Epoch 15/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0070 - accuracy: 0.1800
# Epoch 16/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0068 - accuracy: 0.1800
# Epoch 17/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0064 - accuracy: 0.1800
# Epoch 18/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0061 - accuracy: 0.1800
# Epoch 19/100
# 220/220 [==============================] - 1s 7ms/step - loss: 0.0059 - accuracy: 0.1800
# Epoch 20/100
# 220/220 [==============================] - 1s 7ms/step - loss: 0.0057 - accuracy: 0.1800
# Epoch 21/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0054 - accuracy: 0.1800
# Epoch 22/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0052 - accuracy: 0.1800
# Epoch 23/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0049 - accuracy: 0.1800
# Epoch 24/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0048 - accuracy: 0.1800
# Epoch 25/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0046 - accuracy: 0.1800
# Epoch 26/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0046 - accuracy: 0.1800
# Epoch 27/100
# 220/220 [==============================] - 1s 7ms/step - loss: 0.0045 - accuracy: 0.1800
# Epoch 28/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0044 - accuracy: 0.1800
# Epoch 29/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0043 - accuracy: 0.1800
# Epoch 30/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0042 - accuracy: 0.1800
# Epoch 31/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0040 - accuracy: 0.1800
# Epoch 32/100
# 220/220 [==============================] - 1s 7ms/step - loss: 0.0038 - accuracy: 0.1800
# Epoch 33/100
# 220/220 [==============================] - 1s 7ms/step - loss: 0.0039 - accuracy: 0.1800
# Epoch 34/100
# 220/220 [==============================] - 1s 7ms/step - loss: 0.0038 - accuracy: 0.1800
# Epoch 35/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0038 - accuracy: 0.1800
# Epoch 36/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0036 - accuracy: 0.1800
# Epoch 37/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0037 - accuracy: 0.1800
# Epoch 38/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0036 - accuracy: 0.1800
# Epoch 39/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0035 - accuracy: 0.1800
# Epoch 40/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0035 - accuracy: 0.1800
# Epoch 41/100
# 220/220 [==============================] - 1s 7ms/step - loss: 0.0034 - accuracy: 0.1800
# Epoch 42/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0034 - accuracy: 0.1800
# Epoch 43/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0034 - accuracy: 0.1800
# Epoch 44/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0034 - accuracy: 0.1800
# Epoch 45/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0033 - accuracy: 0.1800
# Epoch 46/100
# 220/220 [==============================] - 1s 7ms/step - loss: 0.0033 - accuracy: 0.1800
# Epoch 47/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0033 - accuracy: 0.1800
# Epoch 48/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0032 - accuracy: 0.1800
# Epoch 49/100
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0033 - accuracy: 0.1800
# Epoch 50/100
# 220/220 [==============================] - 1s 7ms/step - loss: 0.0033 - accuracy: 0.1800
# Epoch 51/100
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0033 - accuracy: 0.1800
# Epoch 52/100
# 220/220 [==============================] - 1s 7ms/step - loss: 0.0033 - accuracy: 0.1800
# Epoch 53/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0033 - accuracy: 0.1800
# Epoch 54/100
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0032 - accuracy: 0.1800
# Epoch 55/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0031 - accuracy: 0.1800
# Epoch 56/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0031 - accuracy: 0.1800
# Epoch 57/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0031 - accuracy: 0.1800
# Epoch 58/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0031 - accuracy: 0.1800
# Epoch 59/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0031 - accuracy: 0.1800
# Epoch 60/100
# 220/220 [==============================] - 1s 7ms/step - loss: 0.0031 - accuracy: 0.1800
# Epoch 61/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0031 - accuracy: 0.1800
# Epoch 62/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0032 - accuracy: 0.1800
# Epoch 63/100
# 220/220 [==============================] - 1s 7ms/step - loss: 0.0031 - accuracy: 0.1800
# Epoch 64/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0031 - accuracy: 0.1800
# Epoch 65/100
# 220/220 [==============================] - 1s 7ms/step - loss: 0.0030 - accuracy: 0.1800
# Epoch 66/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0030 - accuracy: 0.1800
# Epoch 67/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0030 - accuracy: 0.1800
# Epoch 68/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0031 - accuracy: 0.1800
# Epoch 69/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0031 - accuracy: 0.1800
# Epoch 70/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0030 - accuracy: 0.1800
# Epoch 71/100
# 220/220 [==============================] - 1s 7ms/step - loss: 0.0030 - accuracy: 0.1800
# Epoch 72/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0029 - accuracy: 0.1800
# Epoch 73/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0030 - accuracy: 0.1800
# Epoch 74/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0030 - accuracy: 0.1800
# Epoch 75/100
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0029 - accuracy: 0.1800
# Epoch 76/100
# 220/220 [==============================] - 1s 7ms/step - loss: 0.0030 - accuracy: 0.1800
# Epoch 77/100
# 220/220 [==============================] - 1s 7ms/step - loss: 0.0029 - accuracy: 0.1800
# Epoch 78/100
# 220/220 [==============================] - 1s 6ms/step - loss: 0.0030 - accuracy: 0.1800
# Epoch 79/100
# 220/220 [==============================] - 1s 7ms/step - loss: 0.0030 - accuracy: 0.1800
# Epoch 80/100
# 220/220 [==============================] - 1s 7ms/step - loss: 0.0029 - accuracy: 0.1800
# Epoch 81/100
# 220/220 [==============================] - 1s 7ms/step - loss: 0.0029 - accuracy: 0.1800
# Epoch 82/100
# 220/220 [==============================] - 1s 7ms/step - loss: 0.0029 - accuracy: 0.1800
# Epoch 83/100
# 220/220 [==============================] - 1s 7ms/step - loss: 0.0029 - accuracy: 0.1800
# Epoch 84/100
# 220/220 [==============================] - 1s 7ms/step - loss: 0.0029 - accuracy: 0.1800
# Epoch 85/100
# 220/220 [==============================] - 1s 7ms/step - loss: 0.0029 - accuracy: 0.1800
# Epoch 86/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0029 - accuracy: 0.1800
# Epoch 87/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0029 - accuracy: 0.1800
# Epoch 88/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0028 - accuracy: 0.1800
# Epoch 89/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0028 - accuracy: 0.1800
# Epoch 90/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0029 - accuracy: 0.1800
# Epoch 91/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0028 - accuracy: 0.1800
# Epoch 92/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0029 - accuracy: 0.1800
# Epoch 93/100
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0028 - accuracy: 0.1800
# Epoch 94/100
# 220/220 [==============================] - 2s 8ms/step - loss: 0.0029 - accuracy: 0.1800
# Epoch 95/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0028 - accuracy: 0.1800
# Epoch 96/100
# 220/220 [==============================] - 2s 7ms/step - loss: 0.0028 - accuracy: 0.1800
# Epoch 97/100
# 220/220 [==============================] - 1s 7ms/step - loss: 0.0028 - accuracy: 0.1800
# Epoch 98/100
# 220/220 [==============================] - 1s 7ms/step - loss: 0.0029 - accuracy: 0.1800
# Epoch 99/100
# 220/220 [==============================] - 1s 7ms/step - loss: 0.0029 - accuracy: 0.1800
# Epoch 100/100
# 220/220 [==============================] - 1s 7ms/step - loss: 0.0027 - accuracy: 0.1800

# %%
regressor.evaluate(x_test,y_test)
y_pred = regressor.predict(x_test)
real_output = []
for item in y_pred:
    real_output.append((item[0]))
# Out:
# 74/74 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.1628

# %%
value = pd.DataFrame(y_test)
value['predicted'] = np.array(real_output)
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)
value.plot()
